# %% [markdown]
# To facilitate delta comparisons, want to see if the GeoMIP ensembles r1,r2,r3 are initialized with the variables from the RCP4.5 run

# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# let's look at daily max temp data to compare
homedir = "/Volumes/Lab_shared_folder/Datasets/Pinatubo/Total_Effect_Estimation/Data/raw/MPI/"
f_rcp45 = homedir+"tas_day_MPI-ESM-LR_historical_r1i1p1_19800101-19891231.nc"
f_G3 = homedir+"tas_day_MPI-ESM-LR_noVolc1980_r1i1p1_19810101-19901231.nc"

d_G3 = nc.Dataset(f_G3,"r")
d_rcp45 = nc.Dataset(f_rcp45,"r")

# %%
# Pick the correct day and get the time index for the rcp run
# time_comp = d_G3.variables['time'][0]
# ix = np.argwhere(d_rcp45.variables['time'] == time_comp)[0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-609bd1b1b12b> in <module>()
#       1 # Pick the correct day and get the time index for the rcp run
#       2 time_comp = d_G3.variables['time'][0]
# ----> 3 ix = np.argwhere(d_rcp45.variables['time'] == time_comp)[0][0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# slice the two model outputs
o_G3 = d_G3.variables['tas'][0,:,:]
o_rcp45 = d_rcp45.variables['tas'][366,:,:]

# %%
plt.imshow(o_G3 - o_rcp45)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1116f7d88>

# %%
plt.imshow(o_rcp45)

# %%
plt.imshow(o_G3 - o_rcp45)

# %% [markdown]
# We can see that the different ensemble members show fairly different patterns on the first day of the G3 model, but the same ensemble members show much more homogeneous maps of max temp. I think the small deviations in these maps are likely caused by the beginning of aerosol deployment and the multiple timesteps that are included in this dailiy measurement. The initial aerosol deployment likely already has a small effect on max temp around the world. But it's clear that the similarly numbered ensembles are MUCH more similar than the differently numbered ensembles. Because my email question about this went unanswered, I'm assuming this as evidence that the same ensembles are comparable across CMIP and GeoMIP projects, for the Had2GEM-ES model.
#
# -Ian
